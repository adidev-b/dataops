# %%
import pandas as pd

# %%
data = pd.read_csv(r"E:\Big Data\datasets\3. Police Data.csv")

# %%
data
# Out:
#        stop_date stop_time  country_name driver_gender  driver_age_raw  \
# 0       1/2/2005      1:55           NaN             M          1985.0
# 1      1/18/2005      8:15           NaN             M          1965.0
# 2      1/23/2005     23:15           NaN             M          1972.0
# 3      2/20/2005     17:15           NaN             M          1986.0
# 4      3/14/2005     10:00           NaN             F          1984.0
# ...          ...       ...           ...           ...             ...
# 65530  12/6/2012     17:54           NaN             F          1987.0
# 65531  12/6/2012     22:22           NaN             M          1954.0
# 65532  12/6/2012     23:20           NaN             M          1985.0
# 65533  12/7/2012      0:23           NaN           NaN             NaN
# 65534  12/7/2012      0:30           NaN             F          1985.0
#
#        driver_age driver_race                   violation_raw  violation  \
# ...

# %%
# Gives the count of not null columns in a dataframe

data.count()
# Out:
# stop_date             65535
# stop_time             65535
# country_name              0
# driver_gender         61474
# driver_age_raw        61481
# driver_age            61228
# driver_race           61475
# violation_raw         61475
# violation             61475
# search_conducted      65535
# search_type            2479
# stop_outcome          61475
# is_arrested           61475
# stop_duration         61475
# drugs_related_stop    65535
# dtype: int64

# %%
# remove column having all null values 

data.drop(columns='country_name',inplace=True)

# %%
data.tail(20)
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 65515  12/6/2012     10:42             M          1952.0        60.0
# 65516  12/6/2012     10:52             M          1988.0        24.0
# 65517  12/6/2012     11:00             M          1969.0        43.0
# 65518  12/6/2012     11:18             M          1994.0        18.0
# 65519  12/6/2012     11:40             F          1985.0        27.0
# 65520  12/6/2012     12:43             M          1953.0        59.0
# 65521  12/6/2012     14:00             F          1992.0        20.0
# 65522  12/6/2012     14:17             M          1980.0        32.0
# 65523  12/6/2012     14:33             M          1967.0        45.0
# 65524  12/6/2012     15:06             F          1974.0        38.0
# 65525  12/6/2012     15:09             M          1980.0        32.0
# 65526  12/6/2012     15:22             M          1982.0        30.0
# 65527  12/6/2012     15:26             F          1981.0        31.0
# ...

# %%
data['violation'].unique()
# Out:
# array(['Speeding', 'Other', 'Equipment', 'Moving violation', nan,
#        'Registration/plates', 'Seat belt'], dtype=object)

# %%
# For Speeding, were Men or Women stopped more often 

data[data['violation'] == 'Speeding']['driver_gender'].value_counts()
# Out:
# M    25517
# F    11686
# Name: driver_gender, dtype: int64

# %%
# Does gender affect who gets searched during a stop

data.groupby('driver_gender').search_conducted.sum()
# Out:
# driver_gender
# F     366
# M    2113
# Name: search_conducted, dtype: int64

# %%
data.search_conducted.value_counts() #cross verifying the number of times search was conducted
# Out:
# False    63056
# True      2479
# Name: search_conducted, dtype: int64

# %%
data.dtypes
# Out:
# stop_date              object
# stop_time              object
# driver_gender          object
# driver_age_raw        float64
# driver_age            float64
# driver_race            object
# violation_raw          object
# violation              object
# search_conducted         bool
# search_type            object
# stop_outcome           object
# is_arrested            object
# stop_duration          object
# drugs_related_stop       bool
# dtype: object

# %%
data['stop_duration'].value_counts()
# Out:
# 0-15 Min     47379
# 16-30 Min    11448
# 30+ Min       2647
# 2                1
# Name: stop_duration, dtype: int64

# %%
# Describe method to get the statistics of any given column

data.groupby('violation').driver_age.describe()
# Out:
#                        count       mean        std   min   25%   50%   75%  \
# violation
# Equipment             6507.0  31.682957  11.380671  16.0  23.0  28.0  39.0
# Moving violation     11876.0  36.736443  13.258350  15.0  25.0  35.0  47.0
# Other                 3477.0  40.362381  12.754423  16.0  30.0  41.0  50.0
# Registration/plates   2240.0  32.656696  11.150780  16.0  24.0  30.0  40.0
# Seat belt                3.0  30.333333  10.214369  23.0  24.5  26.0  34.0
# Speeding             37120.0  33.262581  12.615781  15.0  23.0  30.0  42.0
#
#                       max
# violation
# Equipment            81.0
# Moving violation     86.0
# Other                86.0
# Registration/plates  74.0
# Seat belt            42.0
# Speeding             88.0
